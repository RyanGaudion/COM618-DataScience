# %%
import pandas as pd
df = pd.read_csv(r'../data/ch2_co2_levels.csv')
print(df)
df.columns
# Out:
#        datestamp    co2
# 0     1958-03-29  316.1
# 1     1958-04-05  317.3
# 2     1958-04-12  317.6
# 3     1958-04-19  317.5
# 4     1958-04-26  316.4
# ...          ...    ...
# 2279  2001-12-01  370.3
# 2280  2001-12-08  370.8
# 2281  2001-12-15  371.2
# 2282  2001-12-22  371.3
# 2283  2001-12-29  371.5
#
# [2284 rows x 2 columns]
# Index(['datestamp', 'co2'], dtype='object')

# %%
print(df.head(n=5))
# Out:
#     datestamp    co2
# 0  1958-03-29  316.1
# 1  1958-04-05  317.3
# 2  1958-04-12  317.6
# 3  1958-04-19  317.5
# 4  1958-04-26  316.4

# %%
print(df.tail(n=5))
# Out:
#        datestamp    co2
# 2279  2001-12-01  370.3
# 2280  2001-12-08  370.8
# 2281  2001-12-15  371.2
# 2282  2001-12-22  371.3
# 2283  2001-12-29  371.5

# %%
print(df.dtypes)
# Out:
# datestamp     object
# co2          float64
# dtype: object

# %%
print(df.dtypes)
# Out:
# datestamp     object
# co2          float64
# dtype: object

# %%
df['datestamp'] = pd.to_datetime(df['datestamp'])

# %%
print(df.dtypes)
# Out:
# datestamp    datetime64[ns]
# co2                 float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = df.set_index('datestamp')
df.plot()
plt.show()

# %%
plt.style.use('dark_background')
df.plot()
plt.show()

# %%
ax = df.plot(color='blue')
ax.set_xlabel('Date')
ax.set_ylabel('The values of my Y axis')
ax.set_title('The title of my plot')
plt.show()

# %%
ax = df.plot(figsize=(12, 5), fontsize=12,
linewidth=3, linestyle='--')
ax.set_xlabel('Date', fontsize=16)
ax.set_ylabel('The values of my Y axis', fontsize=16)
ax.set_title('The title of my plot', fontsize=16)
plt.show()

# %%
import pandas as pd
df2 = pd.read_csv(r'../data/ch1_discoveries.csv')

# %%
print(df2.dtypes)
# Out:
# date    object
# Y        int64
# dtype: object

# %%
pd.to_datetime(df2['date'])
# Out:
# 0    1860-01-01
# 1    1861-01-01
# 2    1862-01-01
# 3    1863-01-01
# 4    1864-01-01
#         ...
# 95   1955-01-01
# 96   1956-01-01
# 97   1957-01-01
# 98   1958-01-01
# 99   1959-01-01
# Name: date, Length: 100, dtype: datetime64[ns]

# %%
print(df2.dtypes)
# Out:
# date    object
# Y        int64
# dtype: object

# %%
df2['date'] = pd.to_datetime(df2['date'])

# %%
print(df2.dtypes)
# Out:
# date    datetime64[ns]
# Y                int64
# dtype: object

# %%
import matplotlib.pyplot as plt
import pandas as pd
df2 = df2.set_index('date')
df2.plot()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
df2_subset = df2 ['01-01-1860':'01-01-1888']

# %%
ax = df2_subset.plot(color='blue', fontsize=14)
plt.show()

# %%
print(df2_subset)
# Out:
#              Y
# date
# 1860-01-01   5
# 1861-01-01   3
# 1862-01-01   0
# 1863-01-01   2
# 1864-01-01   0
# 1865-01-01   3
# 1866-01-01   2
# 1867-01-01   3
# 1868-01-01   6
# 1869-01-01   1
# 1870-01-01   2
# 1871-01-01   1
# 1872-01-01   2
# 1873-01-01   1
# 1874-01-01   3
# 1875-01-01   3
# 1876-01-01   3
# 1877-01-01   5
# 1878-01-01   2
# 1879-01-01   4
# 1880-01-01   4
# 1881-01-01   0
# 1882-01-01   2
# 1883-01-01   3
# 1884-01-01   7
# 1885-01-01  12
# 1886-01-01   3
# 1887-01-01  10
# 1888-01-01   9

# %%
# ax = df2_subset.plot(color='yellow')
# ax.set_xlabel('Date')
# ax.set_ylabel('Number of great discoveries')
# ax.axvline('1969-01-01', color='red', linestyle='--')
# ax.axhline(4, color='green', linestyle='--')
# ax.axvspan('01-01-1888', '01-01-1900', color='red',
# alpha=0.3)
# ax.axhspan(8, 6, color='green', alpha=0.3)


plt.style.use('classic')
ax = df2_subset.plot(figsize=(12,5), fontsize=12, linewidth=3, linestyle='--')
ax.set_xlabel('Date', fontsize=16)
ax.set_ylabel('Number of discoveries', fontsize=16)
ax.set_title('Time series', fontsize=16)
plt.axvline('01-01-1875', color='red', linestyle='--')
plt.axhline(4, color='green', linestyle='solid')
plt.axvspan('01-01-1885', '01-01-1890', color='red', alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\VSCode\Uni\COM618-DataScience\InClass\Week5\venv\lib\site-packages\matplotlib\axis.py:1736, in Axis.convert_units(self, x)
#    1735 try:
# -> 1736     ret = self.converter.convert(x, self.units, self)
#    1737 except Exception as e:
#
# File C:\VSCode\Uni\COM618-DataScience\InClass\Week5\venv\lib\site-packages\matplotlib\category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File C:\VSCode\Uni\COM618-DataScience\InClass\Week5\venv\lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# ...
